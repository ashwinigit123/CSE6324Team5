# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinigit123/CSE6324Team5/blob/main/Iteration1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/ashwinigit123/CSE6324Team5/main/MATC_Projects1.csv'
df1 = pd.read_csv(url)
df1.head()
# Out:
#     id  ... num_model_file
# 0  261  ...              1
# 1  266  ...             15
# 2  268  ...              2
# 3  722  ...              2
# 4  724  ...              2
#
# [5 rows x 18 columns]
