# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinigit123/CSE6324Team5/blob/main/Iteration1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/ashwinigit123/CSE6324Team5/main/MATC_Projects.csv'
df1 = pd.read_csv(url)
df1 = df1.dropna(axis=1)
df1.drop('mathworks_url', inplace=True, axis=1)
df1.drop('author_uri', inplace=True, axis=1)
df1.drop('published', inplace=True, axis=1)
df1.drop('updated', inplace=True, axis=1)
df1.drop('no_of_comments', inplace=True, axis=1)
df1.drop('no_of_ratings', inplace=True, axis=1)
df1.drop('average_rating', inplace=True, axis=1)
df1.drop('downloads', inplace=True, axis=1)
df1.drop('download_link', inplace=True, axis=1)
df1.drop('license', inplace=True, axis=1)
df1.drop('num_model_file', inplace=True, axis=1)
df1.head(5)
# Out:
#     id  ...                                        model_files
# 0  261  ...                                            RF.mdl,
# 1  266  ...  smxl.mdl,examples/vrsvdex.mdl,examples/vrranke...
# 2  268  ...  trimmod/trimtest/trimtest_with_vector_outport....
# 3  722  ...  bluetooth.mdl,R12.1 Original Version/bluetooth...
# 4  724  ...          dtmf.mdl,R12.1 Original Version/dtmf.mdl,
#
# [5 rows x 6 columns]

# %%
df1.groupby('title').count()
# Out:
#                                                     id  ...  model_files
# title                                                   ...
#  "Getting Started with Simulink for Controls" e...   1  ...            1
#  HYBRID ELECTRIC POWER SYSTEM  UTILITY DESIGNED      1  ...            1
#  Longitudinal Vehicle Dynamics                       1  ...            1
#  single phase two level Inverter                     1  ...            1
# "COMM" : Commande et Observation Mono- et Multi...   1  ...            1
# ...                                                 ..  ...          ...
# zvs buck, boost converter                            1  ...            1
# Ćuk Converter                                        1  ...            1
# Пакет моделей к демонстрационному заданию            1  ...            1
# ِABB Automatic Generation Control (frequency re...   1  ...            1
# ِAnt Colony Optimization for PID Controller of ...   1  ...            1
#
# [2679 rows x 5 columns]

# %%
df1.groupby('author_name').count()
# Out:
#                  id  title  summary  content  model_files
# author_name
# A.Delavari        4      4        4        4            4
# ABHILASH SINGH    6      6        6        6            6
# ABHISHEK RANJAN   1      1        1        1            1
# ABID MANSURI      1      1        1        1            1
# ADITYA KESHRI     1      1        1        1            1
# ...              ..    ...      ...      ...          ...
# zhaohui ni        1      1        1        1            1
# zubair            2      2        2        2            2
# zuhair Ahmed      1      1        1        1            1
# Çağlar  İŞLEK     3      3        3        3            3
# Özgür Alpan       1      1        1        1            1
#
# [1096 rows x 5 columns]

# %%
file = 'https://raw.githubusercontent.com/ashwinigit123/CSE6324Team5/main/MATC_Hierar_Info.csv'
df2 = pd.read_csv(file)
df2.head(5)
# Out:
#    M_ID  File_id  ... Conn_count_hidden_only Child_model_count
# 0     1    10335  ...                      0                 1
# 1     2    10335  ...                      0                 1
# 2     3    10335  ...                      0                 0
# 3     4    10439  ...                      0                 7
# 4     5    10439  ...                      0                 0
#
# [5 rows x 9 columns]

# %%
df2.groupby('File_id').count()
# Out:
#          M_ID  Model_Name  ...  Conn_count_hidden_only  Child_model_count
# File_id                    ...
# 266        18          18  ...                      18                 18
# 268         4           4  ...                       4                  4
# 722         4           4  ...                       4                  4
# 724        10          10  ...                      10                 10
# 746         6           6  ...                       6                  6
# ...       ...         ...  ...                     ...                ...
# 73964       3           3  ...                       3                  3
# 73974       3           3  ...                       3                  3
# 73977      21          21  ...                      21                 21
# 74021       3           3  ...                       3                  3
# 74062       3           3  ...                       3                  3
#
# [2704 rows x 8 columns]

# %%
f2='https://raw.githubusercontent.com/ashwinigit123/CSE6324Team5/main/MATC_Subsys_Info.csv'
df3 = pd.read_csv(f2)
df3.head(5)
# Out:
#    S_ID  File_id  ...                                     Subsystem Block_count
# 0     1    10335  ...                       gpsnoise/MultibandNoise          13
# 1     2    10335  ...                  gpsnoise/MultibandNoise/IIR2           3
# 2     3    10439  ...       EngineControl/Copying PSP output to LED           2
# 3     4    10439  ...  EngineControl/Crankshaft Simulation (MPIO14)           2
# 4     5    10439  ...    EngineControl/Flywheel Simulation (MPIO12)           2
#
# [5 rows x 7 columns]

# %%
print('df1 contains: ', len(df1), 'project records')
# Out:
# df1 contains:  2724 project records

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import nltk
nltk.download('punkt')
# df1["tokens"] = df1["summary"].apply(nltk.word_tokenize)
# df1.head(5)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
def tokenizeSummary(data):
    summary = data
    vocab = []
    for summ in summary:
        for word in summ.split(' '):
                vocab.append(word)
    return vocab

# %%
tokens = tokenizeSummary(list(list(zip(*df1.values))[3]))
print(tokens)
# Out:
# ['A', 'collection', 'of', 'functions,', 'scripts,', '&', 'Simulink', 'models', 'useful', 'for', 'designing', 'and', 'analyzing', 'RF', 'systems', 'The', 'Simulink', 'MatriX', 'Library', '(SMXL)', '-', 'a', 'collection', 'of', 'blocks', 'that', 'handle', 'matrices', 'in', 'Simulink.', 'TrimMod', 'finds', 'the', 'trim', 'point', '(equilibrium)', 'of', 'a', 'Simulink', 'system.', 'Bluetooth', 'modulation', 'and', 'frequency', 'hopping', 'DTMF', 'generator', 'and', 'receiver', 'IS-95A', 'CDMA', 'Power', 'Control', 'IS-95A', 'Mobile', 'Phone', 'Call', 'Processing', 'Bluetooth', 'Voice', 'Transmission', 'Adaptive', 'Neural', 'Networks', 'A', 'Simulink', 'wavelet', 'library', 'Nonlinear', '6DOF', 'Model', 'of', 'an', 'Underwater', 'Vehicle', 'Simulink', 'blocks', 'for', 'pressure', 'and', 'flow', 'transients', 'in', 'pipelines.', 'Simulink®', 'and', 'Stateflow®', 'model', 'of', 'a', 'simple', 'packet', 'switch.', 'XY', 'Graph', 'Autoscale', 'block', 'for', 'Simulink®', 'A', 'simulink', 'model', 'which', 'generates', 'a', 'single', 'pulse', 'of', 'all', 'definable', 'parameters.', 'NASA', 'HL-20', 'Lifting', 'Body', 'Airframe', 'Modeled', 'with', 'Simulink', 'and', 'Aerospace', 'Blockset.', 'Simulink', 'model', 'of', 'a', '3-band', 'parametric', 'equalizer', 'controlled', 'by', 'a', 'user-friendly', 'GUI.', 'Simulink®', 'and', 'Stateflow®', 'model', 'of', 'a', 'full', 'duplex', 'Bluetooth®', 'communication', 'link.', 'Model', 'and', 'simulate', 'the', 'physical', 'components', 'and', 'synthesize', 'controllers', 'of', 'the', 'Stewart', 'Platform.', 'Stand', 'alone', 'application', 'example', 'using', 'rapid', 'simulation', 'file.', 'Companion', 'Software.', 'Virtual', 'Reality', 'toolbox', 'interface', 'for', 'airplanes.', 'Stateflow®', 'Model', 'of', 'the', '10Base-T', 'Ethernet', 'and', 'CSMA/CD', 'Protocol.', 'Companion', 'Software', 'for', '"Simulink', '5:', 'Fundamentos".', 'The', 'Aircraft', 'Library', 'A', 'Simulink', 'Blockset', 'for', 'the', 'purpose', 'of', 'simulating', 'servo', 'systems.', 'Tutorial', 'and', 'examples', 'of', 'how', 'to', 'import', 'C', 'code', 'into', 'Simulink.', 'Markov', 'Chain', 'Model', 'of', 'RADAR', 'Detector', 'Simulink', 'library', 'for', 'DDE', 'communication.', 'Use', 'a', 'single', 'Simulink', 's-function', 'block', 'to', 'access', 'multiple', 's-functions.', 'Example', 'of', 'displaying', 'and', 'reducing', 'an', 'image', 'on', 'a', 'Simulink', 'block.', 'IEEE', '802.11a', 'WLAN', 'physical', 'layer', 'model,', 'with', 'demonstration', 'of', 'adaptive', 'modulation', 'and', 'coding.', 'This', 'simulation', 'simulates', 'coded', 'OFDM', 'using', 'RS', 'Code', 'over', 'wireless', 'channel.', '1903', 'Wright', 'Flyer', 'modeled', 'with', 'Simulink,', 'Aerospace', 'Blockset', 'and', 'Virtual', 'Reality', 'Tool.', 'A', 'collection', 'of', 'MATLAB', 'files,', 'useful', 'for', 'analyzing', 'inverted', 'pendulum', '&', 'designing', 'controller', 'for', 'it.', 'Rapid', 'prototyping', 'using', 'C6711', 'This', 'application', 'shows', 'how', 'models', 'based', 'on', 'a', 'system', 'of', 'ODEs', 'are', 'simulated.', 'Fairly', 'detailed', 'simulation', 'of', 'a', 'tennis', 'ball', 'flight', 'and', 'bounce.', 'Explores', 'using', 'the', 'Simulink', 'Debugger', 'to', 'extract', 'information.', 'Principal', 'component', 'analysis', 'of', 'a', 'matrix', 'done', 'within', 'Simulink.', 'Interactive', 'simulation', 'of', 'a', 'PID', 'with', 'autotuning.', 'Multitrack', '3D', 'Simulink', 'Scope', 'This', 'is', 'a', 'demonstration', 'of', 'the', 'Embedded', 'MATLAB', 'Function', 'Block,', 'using', 'a', 'portable', 'random', 'number', 'genera', 'Demo', 'models', 'from', 'the', 'June', '2004', 'News', '&', 'Notes', 'article,', '"Logic', 'Design', 'Using', 'Stateflow', 'Truth', 'Tables".', 'Motion', 'detection', 'algorithm', 'in', 'Simulink', 'using', 'the', 'Image', 'Acquisition', 'and', 'Signal', 'Processing', 'Toolbox.', 'Illustrates', 'the', 'relationships', 'between', 'time', 'and', 'frequency', 'parameters', 'u ...

# %% [markdown]
# Reference for below code: https://shravan-kuchkula.github.io/clustering_movie_plots/#
#
# https://www.hindawi.com/journals/sp/2020/5812715/

# %%
import re
from nltk.stem.snowball import SnowballStemmer

def stemTokens(text):
    #step 1: convert the input text to tokens
    tokens = [word for x in nltk.sent_tokenize(text) for word in nltk.word_tokenize(x)]

    #step 2: Filter the tokens,  remove noise, conevert into small case.
    filtered_tokens = [token for token in tokens if re.search('[a-zA-Z]', token)]
    print("Filtered Tokens:",filtered_tokens)

    #step 3: Stemming the filtered tokens
    stemmer = SnowballStemmer("english")
    stems = [stemmer.stem(word) for word in filtered_tokens]

    return stems
stemmedTokens = stemTokens("this is a sample text for tokenization")
print('Stemmed tokens:',stemmedTokens)
# Out:
# Filtered Tokens: ['this', 'is', 'a', 'sample', 'text', 'for', 'tokenization']
# Stemmed tokens: ['this', 'is', 'a', 'sampl', 'text', 'for', 'token']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate TfidfVectorizer object with stopwords and tokenizer
# parameters for efficient processing of text
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=stemTokens,
                                 ngram_range=(1,3))

# %%
tfidf_matrix =  tfidf_vectorizer.fit_transform([x for x in df1['summary']])


print(tfidf_matrix.shape)
# Out:
# Filtered Tokens: ['alone']
# Filtered Tokens: ['therein']
# Filtered Tokens: ['thick']
# Filtered Tokens: ['seemed']
# Filtered Tokens: ['forty']
# Filtered Tokens: ['hundred']
# Filtered Tokens: ['already']
# Filtered Tokens: ['its']
# Filtered Tokens: ['do']
# Filtered Tokens: ['same']
# Filtered Tokens: ['their']
# Filtered Tokens: ['see']
# Filtered Tokens: ['be']
# Filtered Tokens: ['eg']
# Filtered Tokens: ['nor']
# Filtered Tokens: ['became']
# Filtered Tokens: ['system']
# Filtered Tokens: ['none']
# Filtered Tokens: ['done']
# Filtered Tokens: ['former']
# Filtered Tokens: ['to']
# Filtered Tokens: ['that']
# Filtered Tokens: ['thereafter']
# Filtered Tokens: ['both']
# Filtered Tokens: ['thence']
# Filtered Tokens: ['whenever']
# Filtered Tokens: ['such']
# Filtered Tokens: ['here']
# Filtered Tokens: ['again']
# Filtered Tokens: ['by']
# Filtered Tokens: ['even']
# Filtered Tokens: ['de']
# Filtered Tokens: ['there']
# Filtered Tokens: ['toward']
# Filtered Tokens: ['part']
# Filtered Tokens: ['we']
# Filtered Tokens: ['would']
# Filtered Tokens: ['an']
# Filtered Tokens: ['towards']
# Filtered Tokens: ['four']
# Filtered Tokens: ['how']
# Filtered Tokens: ['out']
# Filtered Tokens: ['through']
# Filtered Tokens: ['are']
# Filtered Tokens: ['thin']
# Filtered Tokens: ['couldnt']
# Filtered Tokens: ['mill']
# Filtered Tokens: ['upon']
# Filtered Tokens: ['cry']
# Filtered Tokens: ['myself']
# Filtered Tokens: ['whereafter']
# Filtered Tokens: ['ours']
# Filtered Tokens: ['some']
# Filtered Tokens: ['these']
# Filtered Tokens: ['becomes']
# Filtered Tokens: ['ten']
# Filtered Tokens: ['elsewhere']
# Filtered Tokens: ['bottom']
# Filtered Tokens: ['each']
# Filtered Tokens: ['whereby']
# Filtered Tokens: ['which']
# Filtered Tokens: ['beyond']
# Filtered Tokens: ['thereby']
# Filtered Tokens: ['off']
# Filtered Tokens: ['fire']
# Filtered Tokens: ['else']
# Filtered Tokens: ['more']
# Filtered Tokens: ['this']
# Filtered Tokens: ['go']
# Filtered Tokens: ['might']
# Filtered Tokens: ['eight']
# Filtered Tokens: ['of']
# Filtered Tokens: ['been']
# Filtered Tokens: ['but']
# Filtered Tokens: ['namely']
# Filtered Tokens: ['least']
# Filtered Tokens: ['seeming']
# Filtered Tokens: ['between']
# Filtered Tokens: ['anyhow']
# Filtered Tokens: ['themselves']
# Filtered Tokens: ['anywhere']
# Filtered Tokens: ['give']
# Filtered Tokens: ['must']
# Filtered Tokens: ['us']
# Filtered Tokens: ['anyway']
# Filtered Tokens: ['had']
# Filtered Tokens: ['thus']
# Filtered Tokens: ['many']
# Filtered Tokens: ['un']
# Filtered Tokens: ['will']
# Filtered Tokens: ['among']
# Filtered Tokens: ['he']
# Filtered Tokens: ['ourselves']
# Filtered Tokens: ['yourselves']
# Filtered Tokens: ['sometimes']
# Filtered Tokens: ['keep']
# Filtered Tokens: ['rather']
# Filtered Tokens: ['everywhere']
# Filtered Tokens: ['afterwards']
# Filtered Tokens: ['have']
# Filtered Tokens: ['never']
# Filtered Tokens: ['whom']
# Filtered Tokens: ['until']
# Filtered Tokens: ['together']
# Filtered Tokens: ['has']
# Filtered Tokens: ['i']
# Filtered Tokens: ['amongst']
# Filtered Tokens: ['at']
# Filtered Tokens: ['moreover']
# Filtered Tokens: ['hasnt']
# Filtered Tokens: ['my']
# Filtered Tokens: ['wherein']
# Filtered Tokens: ['less']
# Filtered Tokens: ['the']
# Filtered Tokens: ['while']
# Filtered Tokens: ['hers']
# Filtered Tokens: ['when']
# Filtered Tokens: ['top']
# Filtered Tokens: ['those']
# Filtered Tokens: ['whither']
# Filtered Tokens: ['co']
# Filtered Tokens: ['fill']
# Filtered Tokens: ['himself']
# Filtered Tokens: ['hereafter']
# Filtered Tokens: ['show']
# Filtered Tokens: ['formerly']
# Filtered Tokens: ['put']
# Filtered Tokens: ['for']
# Filtered Tokens: ['get']
# Filtered Tokens: ['her']
# Filtered Tokens: ['also']
# Filtered Tokens: ['whence']
# Filtered Tokens: ['further']
# Filtered Tokens: ['along']
# Filtered Tokens: ['everyone']
# Filtered Tokens: ['your']
# Filtered Tokens: ['sixty']
# Filtered Tokens: ['whole']
# Filtered Tokens: ['can']
# Filtered Tokens: ['throughout']
# Filtered Tokens: ['something']
# Filtered Tokens: ['made']
# Filtered Tokens: ['ltd']
# Filtered Tokens: ['during']
# Filtered Tokens: ['third']
# Filtered Tokens: ['amoungst']
# Filtered Tokens: ['since']
# Filtered Tokens: ['hence']
# Filtered Tokens: ['other']
# Filtered Tokens: ['am']
# Filtered Tokens: ['always']
# Filtered Tokens: ['on']
# Filtered Tokens: ['what']
# Filtered Tokens: ['nine']
# Filtered Tokens: ['seem']
# Filtered Tokens: ['above']
# Filtered Tokens: ['onto']
# Filtered Tokens: ['per']
# Filtered Tokens: ['most']
# Filtered Tokens: ['should']
# Filtered Tokens: ['mine']
# Filtered Tokens: ['yourself']
# Filtered Tokens: ['itself']
# Filtered Tokens: ['yours']
# Filtered Tokens: ['may']
# Filtered Tokens: ['up']
# Filtered Tokens: ['move']
# Filtered Tokens: ['could']
# Filtered Tokens: ['besides']
# Filtered Tokens: ['one']
# Filtered Tokens: ['in']
# Filtered Tokens: ['from']
# Filtered Tokens: ['were']
# Filtered Tokens: ['others']
# Filtered Tokens: ['and']
# Filtered Tokens: ['nowhere']
# Filtered Tokens: ['thereupon']
# Filtered Tokens: ['noone']
# Filtered Tokens: ['whose']
# Filtered Tokens: ['too']
# Filtered Tokens: ['latterly']
# Filtered Tokens: ['anyone']
# Filtered Tokens: ['with']
# Filtered Tokens: ['behind']
# Filtered Tokens: ['down']
# Filtered Tokens: ['if']
# Filtered Tokens: ['fifty']
# Filtered Tokens: ['re']
# Filtered Tokens: ['under']
# Filtered Tokens: ['eleven']
# Filtered Tokens: ['serious']
# Filtered Tokens: ['back']
# Filtered Tokens: ['once']
# Filtered Tokens: ['herself']
# Filtered Tokens: ['detail']
# Filtered Tokens: ['interest']
# Filtered Tokens: ['next']
# Filtered Tokens: ['them']
# Filtered Tokens: ['across']
# Filtered Tokens: ['whereas']
# Filtered Tokens: ['against']
# Filtered Tokens: ['well']
# Filtered Tokens: ['take']
# Filtered Tokens: ['beside']
# Filtered Tokens: ['where']
# Filtered Tokens: ['due']
# Filtered Tokens: ['empty']
# Filtered Tokens: ['side']
# Filtered Tokens: ['describe']
# Filtered Tokens: ['found']
# Filtered Tokens: ['into']
# Filtered Tokens: ['than']
# Filtered Tokens: ['although']
# Filtered Tokens: ['nevertheless']
# Filtered Tokens: ['three']
# Filtered Tokens: ['a']
# Filtered Tokens: ['via']
# Filtered Tokens: ['ie']
# Filtered Tokens: ['inc']
# Filtered Tokens: ['seems']
# Filtered Tokens: ['except']
# Filtered Tokens: ['before']
# Filtered Tokens: ['becoming']
# Filtered Tokens: ['often']
# Filtered Tokens: ['bill']
# Filtered Tokens: ['whether']
# Filtered Tokens: ['can', 'not']
# Filtered Tokens: ['latter']
# Filtered Tokens: ['around']
# Filtered Tokens: ['as']
# Filtered Tokens: ['after']
# Filtered Tokens: ['full']
# Filtered Tokens: ['otherwise']
# Filtered Tokens: ['cant']
# Filtered Tokens: ['though']
# Filtered Tokens: ['perhaps']
# Filtered Tokens: ['become']
# Filtered Tokens: ['no']
# Filtered Tokens: ['hereby']
# Filtered Tokens: ['nothing']
# Filtered Tokens: ['his']
# Filtered Tokens: ['any']
# Filtered Tokens: ['so']
# Filtered Tokens: ['now']
# Filtered Tokens: ['however']
# Filtered Tokens: ['etc']
# Filtered Tokens: ['enough']
# Filtered Tokens: ['hereupon']
# Filtered Tokens: ['several']
# Filtered Tokens: ['ever']
# Filtered Tokens: ['please']
# Filtered Tokens: ['me']
# Filtered Tokens: ['name']
# Filtered Tokens: ['about']
# Filtered Tokens: ['yet']
# Filtered Tokens: ['over']
# Filtered Tokens: ['not']
# Filtered Tokens: ['nobody']
# Filtered Tokens: ['him']
# Filtered Tokens: ['neither']
# Filtered Tokens: ['herein']
# Filtered Tokens: ['someone']
# Filtered Tokens: ['then']
# Filtered Tokens: ['wherever']
# Filtered Tokens: ['without']
# Filtered Tokens: ['within']
# Filtered Tokens: ['still']
# Filtered Tokens: ['whoever']
# Filtered Tokens: ['indeed']
# Filtered Tokens: ['sometime']
# Filtered Tokens: ['was']
# Filtered Tokens: ['con']
# Filtered Tokens: ['because']
# Filtered Tokens: ['few']
# Filtered Tokens: ['every']
# Filtered Tokens: ['you']
# Filtered Tokens: ['own']
# Filtered Tokens: ['whatever']
# Filtered Tokens: ['call']
# Filtered Tokens: ['twenty']
# Filtered Tokens: ['everything']
# Filtered Tokens: ['another']
# Filtered Tokens: ['or']
# Filtered Tokens: ['fifteen']
# Filtered Tokens: ['therefore']
# Filtered Tokens: ['front']
# Filtered Tokens: ['five']
# Filtered Tokens: ['they']
# Filtered Tokens: ['is']
# Filtered Tokens: ['six']
# Filtered Tokens: ['almost']
# Filtered Tokens: ['somewhere']
# Filtered Tokens: ['who']
# Filtered Tokens: ['anything']
# Filtered Tokens: ['only']
# Filtered Tokens: ['somehow']
# Filtered Tokens: ['thru']
# Filtered Tokens: ['much']
# Filtered Tokens: ['either']
# Filtered Tokens: ['being']
# Filtered Tokens: ['amount']
# Filtered Tokens: ['very']
# Filtered Tokens: ['she']
# Filtered Tokens: ['our']
# Filtered Tokens: ['whereupon']
# Filtered Tokens: ['meanwhile']
# Filtered Tokens: ['why']
# Filtered Tokens: ['it']
# Filtered Tokens: ['beforehand']
# Filtered Tokens: ['last']
# Filtered Tokens: ['twelve']
# Filtered Tokens: ['find']
# Filtered Tokens: ['mostly']
# Filtered Tokens: ['all']
# Filtered Tokens: ['below']
# Filtered Tokens: ['sincere']
# Filtered Tokens: ['two']
# Filtered Tokens: ['first']
# Filtered Tokens: ['a', 'collection', 'of', 'functions', 'scripts', 'simulink', 'models', 'useful', 'for', 'designing', 'and', 'analyzing', 'rf', 'systems']
# Filtered Tokens: ['the', 'simulink', 'matrix', 'library', 'smxl', 'a', 'collection', 'of', 'blocks', 'that', 'handle', 'matrices', 'in', 'simulink']
# Filtered Tokens: ['trimmod', 'finds', 'the', 'trim', 'point', 'equilibrium', 'of', 'a', 'simulink', 'system']
# Filtered Tokens: ['bluetooth', 'modulation', 'and', 'frequency', 'hopping']
# Filtered Tokens: ['dtmf', 'generator', 'and', 'receiver']
# Filtered Tokens: ['is-95a', 'cdma', 'power', 'control']
# Filtered Tokens: ['is-95a', 'mobile', 'phone', 'call', 'processing']
# Filtered Tokens: ['bluetooth', 'voice', 'transmission']
# Filtered Tokens: ['adaptive', 'neural', 'networks']
# Filtered Tokens: ['a', 'simulink', 'wavelet', 'library']
# Filtered Tokens: ['nonlinear', '6dof', 'model', 'of', 'an', 'underwater', 'vehicle']
# Filtered Tokens: ['simulink', 'blocks', 'for', 'pressure', 'and', 'flow', 'transients', 'in', 'pipelines']
# Filtered Tokens: ['simulink®', 'and', 'stateflow®', 'model', 'of', 'a', 'simple', 'packet', 'switch']
# Filtered Tokens: ['xy', 'graph', 'autoscale', 'block', 'for', 'simulink®']
# Filtered Tokens: ['a', 'simulink', 'model', 'which', 'generates', 'a', 'single', 'pulse', 'of', 'all', 'definable', 'parameters']
# Filtered Tokens: ['nasa', 'hl-20', 'lifting', 'body', 'airframe', 'modeled', 'with', 'simulink', 'and', 'aerospace', 'blockset']
# Filtered Tokens: ['simulink', 'model', 'of', 'a', '3-band', 'parametric', 'equalizer', 'controlled', 'by', 'a', 'user-friendly', 'gui']
# Filtered Tokens: ['simulink®', 'and', 'stateflow®', 'model', 'of', 'a', 'full', 'duplex', 'bluetooth®', 'communication', 'link']
# Filtered Tokens: ['model', 'and', 'simulate', 'the', 'physical', 'components', 'and', 'synthesize', 'controllers', 'of', 'the', 'stewart', 'platform']
# Filtered Tokens: ['stand', 'alone', 'application', 'example', 'using', 'rapid', 'simulation', 'file']
# Filtered Tokens: ['companion', 'software']
# Filtered Tokens: ['virtual', 'reality', 'toolbox', 'interface', 'for', 'airplanes']
# Filtered Tokens: ['stateflow®', 'model', 'of', 'the', '10base-t', 'ethernet', 'and', 'csma/cd', 'protocol']
# Filtered Tokens: ['companion', 'software', 'for', 'simulink', 'fundamentos']
# Filtered Tokens: ['the', 'aircraft', 'library']
# Filtered Tokens: ['a', 'simulink', 'blockset', 'for', 'the', 'purpose', 'of', 'simulating', 'servo', 'systems']
# Filtered Tokens: ['tutorial', 'and', 'examples', 'of', 'how', 'to', 'import', 'c', 'code', 'into', 'simulink']
# Filtered Tokens: ['markov', 'chain', 'model', 'of', 'radar', 'detector']
# Filtered Tokens: ['simulink', 'library', 'for', 'dde', 'communication']
# Filtered Tokens: ['use', 'a', 'single', 'simulink', 's-function', 'block', 'to', 'access', 'multiple', 's-functions']
# Filtered Tokens: ['example', 'of', 'displaying', 'and', 'reducing', 'an', 'image', 'on', 'a', 'simulink', 'block']
# Filtered Tokens: ['ieee', '802.11a', 'wlan', 'physical', 'layer', 'model', 'with', 'demonstration', 'of', 'adaptive', 'modulation', 'and', 'coding']
# Filtered Tokens: ['this', 'simulation', 'simulates', 'coded', 'ofdm', 'using', 'rs', 'code', 'over', 'wireless', 'channel']
# Filtered Tokens: ['wright', 'flyer', 'modeled', 'with', 'simulink', 'aerospace', 'blockset', 'and', 'virtual', 'reality', 'tool']
# Filtered Tokens: ['a', 'collection', 'of', 'matlab', 'files', 'useful', 'for', 'analyzing', 'inverted', 'pendulum', 'designing', 'controller', 'for', 'it']
# Filtered Tokens: ['rapid', 'prototyping', 'using', 'c6711']
# Filtered Tokens: ['this', 'application', 'shows', 'how', 'models', 'based', 'on', 'a', 'system', 'of', 'odes', 'are', 'simulated']
# Filtered Tokens: ['fairly', 'detailed', 'simulation', 'of', 'a', 'tennis', 'ball', 'flight', 'and', 'bounce']
# Filtered Tokens: ['explores', 'using', 'the', 'simulink', 'debugger', 'to', 'extract', 'information']
# Filtered Tokens: ['principal', 'component', 'analysis', 'of', 'a', 'matrix', 'done', 'within', 'simulink']
# Filtered Tokens: ['interactive', 'simulation', 'of', 'a', 'pid', 'with', 'autotuning']
# Filtered Tokens: ['multitrack', '3d', 'simulink', 'scope']
# Filtered Tokens: ['this', 'is', 'a', 'demonstration', 'of', 'the', 'embedded', 'matlab', 'function', 'block', 'using', 'a', 'portable', 'random', 'number', 'genera']
# Filtered Tokens: ['demo', 'models', 'from', 'the', 'june', 'news', 'notes', 'article', 'logic', 'design', 'using', 'stateflow', 'truth', 'tables']
# Filtered Tokens: ['motion', 'detection', 'algorithm', 'in', 'simulink', 'using', 'the', 'image', 'acquisition', 'and', 'signal', 'processing', 'toolbox']
# Filtered Tokens: ['illustrates', 'the', 'relationships', 'between', 'time', 'and', 'frequency', 'parameters', 'used', 'in', 'rf', 'blockset']
# Filtered Tokens: ['simulink', 'model', 'and', 'data', 'acquisition', 'toolbox', 'analyze', 'streaming', 'audio', 'from', 'windows', 'soundcard']
# Filtered Tokens: ['linear', 'scaling']
# Filtered Tokens: ['unwraps', 'angles', 'so', 'that', 'continuity', 'is', 'restored']
# Filtered Tokens: ['performs', 'soft-decison', 'viterbi', 'decoding', 'with', 'puncturing', 'over', 'an', 'awgn', 'channel', 'using', 'simulink', 'r']
# Filtered Tokens: ['signal', 'composition/decomposition', 'into', 'different', 'types']
# Filtered Tokens: ['tips', 'on', 'fixed-point', 'modeling', 'and', 'code', 'generation', 'folder', 'fixpt_tips.zip', 'contains', 'referenced', 'files']
# Filtered Tokens: ['physical', 'system', 'model', 'of', 'a', 'hydraulic-electric', 'energy', 'storage', 'device', 'for', 'hybrid', 'automotive']
# Filtered Tokens: ['simulate', 'liqiud', 'level', 'system']
# Filtered Tokens: ['companion', 'software', 'to', 'french', 'book', 'commande', 'et', 'estimation', 'multivariables']
# Filtered Tokens: ['sorts', 'vectors', 'using', 'quicksort']
# Filtered Tokens: ['nonlinear', 'systems', 'with', 'attractors']
# Filtered Tokens: ['self-tuning', 'controllers', 'simulink', 'library', 'standard', 'version']
# Filtered Tokens: ['self-tuning', 'controllers', 'simulink', 'library', 'real', 'time', 'workshop', 'version']
# Filtered Tokens: ['c-code', 's-function', 'tutorial', 'from', 'web', 'seminar']
# Filtered Tokens: ['flags', 'of', 'some', 'countries', 'in', 'simulink']
# Filtered Tokens: ['embedded', 'matlab', 'function', 'blocks', 'that', 'simulate', 'pointing', 'loss', 'and', 'signal', 'obstruction', 'for', 'gaussian']
# Filtered Tokens: ['this', 'program', 'simulate', 'temperature', 'control', 'of', 'one', 'or', 'two', 'series', 'tank']
# Filtered Tokens: ['wraps', 'the', 'input', 'vector', 'into', 'a', 'given', 'hypercuboid']
# Filtered Tokens: ['simple', 'design', 'for', 'helicopter', 'control', 'system']
# Filtered Tokens: ['model', 'gas', 'consumption', 'from', 'gas-source', 'to', 'gas-consumer']
# Filtered Tokens: ['automatically', 'creates', 'the', 'corresponding', 'from-block', 'with', 'blockname', 'and', 'tagname']
# Filtered Tokens: ['saves', 'data', 'to', 'a', 'file', 'at', 'the', 'end', 'of', 'the', 'simulation']
# Filtered Tokens: ['multiband', 'gps', 'noise']
# Filtered Tokens: ['additional', 'i/o', 'blocks', 'for', 'mpc555', 'target', 'specifically', 'targetting', 'tpu', 'functionality']
# Filtered Tokens: ['technical', 'paper', 'and', 'examples', 'on', 'modeling', 'flexibility', 'in', 'simmechanics']
# Filtered Tokens: ['customizable', 'add-on', 'library', 'with', 'a', 'small', 'number', 'of', 'blocks', 'for', 'graphical', 'programming', 'of', 'bond', 'graph', 'models', 'using', 'standard', 'simulink', 'and', 'editor']
# Filtered Tokens: ['dofs', 'suspension', 'model', 'for', 'simulink']
# Filtered Tokens: ['toolbox/blockset', 'about', 'optical', 'comunication', 'system', 'sonet/sdh', 'mapping', 'over', 'fiber', 'optics']
# Filtered Tokens: ['dc', 'motor', 'model', 'simulink', 'model', 'with', 'voltage', 'input', 'speed', 'and', 'current', 'output', 'graph']
# Filtered Tokens: ['a', 'simulink', 'r', 'block', 'for', 'execution', 'control', 'of', 'simulink', 'models']
# Filtered Tokens: ['a', 'simulink', 'model', 'for', 'carrierless', 'amplitude', 'phase', 'modulation', 'cap']
# Filtered Tokens: ['this', 'zip-file', 'contains', 'the', 'models', 'that', 'were', 'discussed', 'in', 'the', 'mathworks', 'webinar', 'entitled', 'stateflow', 'd']
# Filtered Tokens: ['different', 'models', 'of', 'dc', 'motors', 'in', 'simulink', 'r', 'and', 'matlab', 'r']
# Filtered Tokens: ['a', 'set', 'of', 'tools', 'and', 'examples', 'to', 'implement', 'task', 'execution', 'profiling', 'for', 'a', 'real-time', 'workshop', 'target']
# Filtered Tokens: ['the', 'attached', 'script', 'and', 'document', 'help', 'you', 'remove', 'all', 'r11', 'dsp', 'blockset', 'blocks', 'from', 'your', 'models']
# Filtered Tokens: ['demo', 'files', 'from', 'the', 'webinar', 'introduction', 'to', 'optimization', 'with', 'matlab', 'r', 'products', 'oct.']
# Filtered Tokens: ['these', 'files', 'accompany', 'the', 'november', 'article', 'in', 'matlab', 'digest']
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# Filtered Tokens: ['acquire', 'live', 'oscilloscope', 'data', 'directly', 'into', 'simulink', 'model']
# Filtered Tokens: ['this', 'example', 'demonstrates', 'one', 'approach', 'using', 'embedded', 'matlab', 'to', 'output', 'strings', 'from', 'a', 'stateflow', 'char']
# Filtered Tokens: ['this', 'blockset', 'is', 'for', 'modeling', 'and', 'visualization', 'of', 'the', 'dynamics', 'of', 'differential', 'drive', 'vehicle', 'robot']
# Filtered Tokens: ['a', 'simple', 'c', 's-function', 'which', 'reads', 'data', 'from', 'a', 'file', 'during', 'simulation']
# Filtered Tokens: ['this', 'model', 'implements', 'cordic', 'algorithm', 'using', 'embedded', 'matlab', 'blocks']
# Filtered Tokens: ['using', 'simulink', 'with', 'serial', 'devices', 'example', 'model']
# Filtered Tokens: ['example', 'simulink', 'model', 'to', 'support', 'matlab', 'digest', 'article', 'from', 'january']
# Filtered Tokens: ['parallel', 'and', 'co-simulations', 'with', 'simulink', 'r', 'integration', 'with', 'simserver']
# Filtered Tokens: ['pressure', 'temperature', 'or', 'level', 'control', 'of', 'one', 'tank', 'or', 'two', 'series', 'tank', 'interacting', 'or', 'noninteracting']
# Filtered Tokens: ['files', 'from', 'webinar', 'on', 'industrial', 'control', 'of', 'a', 'steel', 'rolling', 'mill']
# Filtered Tokens: ['patterns', 'and', 'examples', 'of', 'various', 'hardware', 'elements', 'implemented', 'using', 'embedded', 'matlab']
# Filtered Tokens: ['simulink', 'model', 'to', 'measure', 'the', 'soil', 'resistivity']
# Filtered Tokens: ['frequency', 'response', 'signal', 'analyzer', 'for', 'simulation', 'control', 'loops', 'and', 'dynamic', 'systems']
# Filtered Tokens: ['a', 'very', 'simple', 'simulations', 'of', 'digital', 'modulations', 'using', 'system', 'generator', 'for', 'xilinx', 'fpgas']
# Filtered Tokens: ['a', 'tutorial', 'showing', 'how', 'phase-locked', 'loops', 'both', 'analog', 'and', 'digital', 'can', 'be', 'efficiently', 'modeling', 'in', 'si']
# Filtered Tokens: ['example', 'models', 'that', 'show', 'the', 'use', 'of', 'diagnostics', 'to', 'improve', 'the', 'model']
# Filtered Tokens: ['using', 'embedded', 'matlab', 'block', 'effectively', 'in', 'simulink']
# Filtered Tokens: ['two', 'communications', 'blockset', 'models', 'that', 'show', 'how', 'to', 'implement', 'a', 'link', 'budget']
# Filtered Tokens: ['templates', 'modeling', 'common', 'schedule', 'implementations']
# Filtered Tokens: ['methods', 'for', 'removing', 'data', 'dependencies', 'with', 'a', 'minimum', 'number', 'of', 'blocks']
# Filtered Tokens: ['this', 'simevents', 'model', 'uses', 'a', 'captured', 'ethereal', 'file', 'as', 'a', 'data', 'source', 'to', 'study', 'queuing', 'performance']
# Filtered Tokens: ['a', 'forced', 'damped', 'driven', 'pendulum', 'exhibits', 'chaotic', 'motion']
# Filtered Tokens: ['functions', 'to', 'easily', 'save', 'xpc', 'file', 'scope', 'data', 'to', 'the', 'target', 'pc', 'as', 'mat', 'files']
# Filtered Tokens: ['impleminting', 'the', 'emergency', 'system', 'ina', 'power', 'susbtation', 'in', 'case', 'of', 'blackout', 'in', 'the', 'main', 'feeder']
# Filtered Tokens: ['a', 'complete', 'projcet', 'build', 'with', 'matlab', 'for', 'image', 'processing', 'robot', 'animation']
# Filtered Tokens: ['this', 'is', 'a', 'library', 'that', 'allows', 'you', 'to', 'send', 'udp', 'messages', 'with', 'simulink', 'r']
# Filtered Tokens: ['generates', 'code', 'for', 'all', 'the', 'test', 'data', 'from', 'a', 'signal', 'builder', 'block']
# Filtered Tokens: ['comedi', 'blocks', 'for', 'code', 'generation', 'with', 'the', 'linux', 'based', 'real-time', 'targets', 'e.g', 'the', 'lnx', 'target']
# Filtered Tokens: ['implementing', 'mealy', 'and', 'moore', 'fsms', 'in', 'an', 'embedded', 'matlab', 'block']
# Filtered Tokens: ['the', 'model', 'provides', 'a', 'simple', 'example', 'on', 'how', 'a', 'client', 'server', 'dialog', 'can', 'be', 'implemented', 'using', 'stateflow']
# Filtered Tokens: ['this', 'example', 'shows', 'how', 'to', 'use', 'embedded', 'matlab', 'to', 'model', 'memory', 'elements']
# Filtered Tokens: ['using', 'bitsliceget', 'and', 'bitconcat', 'functions', 'to', 'implement', 'a', 'byte2tuple', 'converter', 'needed', 'in', 'a', 'dvb', 'system']
# Filtered Tokens: ['this', 'demo', 'shows', 'to', 'call', 'external', 'functions', 'in', 'an', 'embedded', 'matlab', 'block']
# Filtered Tokens: ['implementing', 'various', 'kinds', 'of', 'counters', 'like', 'johnson', 'gray', 'mod', 'counters', 'in', 'embedded', 'matlab']
# Filtered Tokens: ['first', 'principles', 'dynamic', 'simulator', 'of', 'a', 'yeast', 'fermentation', 'bioreactor', 'for', 'ethanol', 'production']
# Filtered Tokens: ['create', 'and', 'simulate', 'up', 'to', 'fourth', 'order', 'trajectories', 'for', 'motion', 'systems', 'doing', 'point-to-point', 'moves']
# Filtered Tokens: ['this', 'demo', 'shows', 'how', 'to', 'use', 'embedded', 'matlab', 'block', 'parameters', 'to', 'control', 'the', 'algorithm', 'behavior']
# Filtered Tokens: ['ofdm', 'implementation', 'using', 'qpsk', 'modulation']
# Filtered Tokens: ['ofdm', 'implementation', 'using', '16-qam', 'modulation']
# Filtered Tokens: ['ofdm', 'implementation', 'using', '64-qam', 'modulation']
# Filtered Tokens: ['this', 'demos', 'shows', 'to', 'serialize', 'an', 'image', 'and', 'apply', 'sobel', 'operators', 'on', 'it', 'to', 'detect', 'its', 'its', 'edges']
# Filtered Tokens: ['ofdm', 'implementation', 'using', 'qpsk', 'modulation']
# Filtered Tokens: ['ofdm', 'implementation', 'using', '16-qam', 'modulation', 'for', 'r14']
# Filtered Tokens: ['ofdm', 'implementation', 'using', '64-qam', 'modulation']
# Filtered Tokens: ['model', 'based', 'design', 'demonstration', 'based', 'on', 'a', 'motion', 'control', 'case', 'study']
# Filtered Tokens: ['simscape', 'tutorial', 'exercises', 'from', 'hands-on', 'workshop', 'events']
# Filtered Tokens: ['a', 'small', 'simulink', 'library', 'to', 'provide', 'performance', 'index', 'measurements']
# Filtered Tokens: ['cycloconverter', 'using', 'thyristors']
# Filtered Tokens: ['this', 'zip-file', 'contains', 'the', 'models', 'used', 'in', 'the', 'webinar', 'entitled', 'stateflow', 'design', 'patterns', 'part', 'iii']
# Filtered Tokens: ['this', 'demo', 'shows', 'how', 'to', 'model', 'a', 'fixed', 'point', 'nco', 'using', 'an', 'embedded', 'matlab', 'block']
# Filtered Tokens: ['demos', 'used', 'in', 'webinar', 'analog', 'circuit', 'effects', 'in', 'signal', 'processing', 'and', 'communication', 'system', 'models']
# Filtered Tokens: ['probes', 'for', 'viewing', 'physical', 'variables']
# Filtered Tokens: ['this', 'code', 'evaluates', 'the', 'determinant', 'of', 'a', 'by', 'matrix', 'in', 'simulink']
# Filtered Tokens: ['this', 'is', 'a', 'simulink', 'block', 'to', 'plot', '3-phase', 'graph', 'during', 'simulation']
# Filtered Tokens: ['this', 'set', 'of', 'simulink', 'models', 'demonstrates', 'how', 'to', 'create', 'a', 'reusable', 'embedded', 'matlab', 'function', 'for', 'scala']
# Filtered Tokens: ['matlab', 'code', 'used', 'in', 'the', 'jan', 'digest', 'article']
# Filtered Tokens: ['this', 'set', 'of', 'models', 'and', 'word', 'documents', 'show', 'an', 'echo', 'canceller', 'development', 'workflow']
# Filtered Tokens: ['a', 'dynamic', 'model', 'of', 'a', 'steam', 'condenser', 'with', 'pid', 'control']
# Filtered Tokens: ['a', 'simulink', 'model', 'to', 'learn', 'the', 'kalman', 'filter', 'for', 'gassian', 'processes']
# Filtered Tokens: ['a', 'simulink', 'model', 'to', 'learn', 'the', 'continuous-time', 'kalman-bucy', 'filter']
# Filtered Tokens: ['a', 'feedback', 'view', 'of', 'kalman', 'filter', 'to', 'gain', 'more', 'useful', 'insights']
# Filtered Tokens: ['this', 'demo', 'shows', 'how', 'to', 'use', 'embedded', 'matlab', 'to', 'compute', 'mod3', 'of', 'a', 'number', 'in', 'a', 'hardware', 'friendly', 'fashio']
# Filtered Tokens: ['model', 'of', 'action', 'potential', 'firing', 'by', 'an', 'a-type', 'nodose', 'neuron']
# Filtered Tokens: ['a', 'simulink', 'model', 'configurable', 'to', 'buck', 'boost', 'and', 'buck-boost', 'dc-dc', 'converters', 'with', 'pwm', 'pi', 'control']
# Filtered Tokens: ['shell', 'extension', 'describing', 'an', 'mdl', 'file', "'s", 'contents', 'created', 'using', 'real-time', 'workshop', 'and', 'stateflow']
# Filtered Tokens: ['a', 'modified', 'version', 'of', 'the', 'shipping', 'demo', 'rf_amp_qam16']
# Filtered Tokens: ['nxtway-gs', 'model-based', 'design', 'based', 'on', 'embedded', 'coder', 'robot', 'nxt']
# Filtered Tokens: ['a', 'simulink', 'model', 'of', 'an', 'evaporator', 'with', 'gradient', 'control']
# Filtered Tokens: ['a', 'pulse', 'generator', 'with', 'amplitude', 'pulse', 'width', 'and', 'pulse', 'period', 'inputs']
# Filtered Tokens: ['calculation', 'of', 'trigonometrical', 'sin', 'and', 'cos', 'functions', 'by', 'cordic']
# Filtered Tokens: ['applications', 'of', 'cordic', 'algorithm']
# Filtered Tokens: ['modeling', 'and', 'simulating', 'mechanical', 'friction', 'in', 'the', 'simulink®', 'and', 'physical', 'modeling', 'environment']
# Filtered Tokens: ['tips', 'on', 'fixed-point', 'modeling', 'and', 'code', 'generation', 'for', 'r2008a', 'includes', 'referenced', 'model', 'files']
# Filtered Tokens: ['target', 'both', 'cores', 'of', 'a', 'bf561', 'microprocessor', 'with', 'real-time', 'workshop', 'embedded', 'coder']
# Filtered Tokens: ['this', 'block', 'outputs', 'a', 'given', 'element', 'of', 'a', 'matrix', 'defined', 'by', 'the', 'raw', 'and', 'the', 'column', 'indices', 'of', 'the', 'elem']
# Filtered Tokens: ['a', 'shaper', 'is', 'presented', 'whose', 'parameters', 'are', 'tuned', 'with', 'genetic', 'alg', 'suitable', 'for', 'unknown', 'dynamics']
# Filtered Tokens: ['simulink', 'realization', 'of', 'morris-lecar', 'neuron', 'model']
# Filtered Tokens: ['files', 'for', 'the', 'joint', 'mathworks', 'and', 'xilinx', 'seminar', 'video', 'surveillance', 'system', 'design']
# Filtered Tokens: ['modeling', 'of', 'dc-dc', 'boost', 'converter', 'using', 'simlink', 'tools', 'with', 'open', 'loop', 'pwm']
# Filtered Tokens: ['a', 'step-by-step', 'tutorial', 'on', 'how', 'to', 'create', 'custom', 'device', 'drivers', 'for', 'xpc', 'target', 'using', 'xpcdrivertool']
# Filtered Tokens: ['mittag-leffler', 'function', 'm-file', 'cmex', 'dll', 'and', 's-function']
# Filtered Tokens: ['the', 'histogram', 'overlay', 'block', 'plots', 'a', 'histogram', 'onto', 'your', 'video', 'in', 'simulink®']
# Filtered Tokens: ['wimax', 'physical', 'and', 'mac', 'layer']
# Filtered Tokens: ['this', 'file', 'contains', 'a', 'guide_simulink_sfunction', 'interface', 'it', 'is', 'a', 'fairly', 'easy', 'and', 'simple', 'application']
# Filtered Tokens: ['real', 'time', 'upadate', 'of', 'simulink', 'scope', 'data', 'on', 'gui', 'gauge', 'and', 'axes']
# Filtered Tokens: ['simulation', 'of', 'a', 'one-legged', 'hopping', 'robot']
# Filtered Tokens: ['simulating', 'a', '2-d', 'system', 'for', 'multiple', 'initial', 'points']
# Filtered Tokens: ['these', 'are', 'the', 'files', 'from', 'the', 'image', 'and', 'video', 'processing', 'with', 'simulink', 'webinar']
# Filtered Tokens: ['example', 'timeout', 'for', 'long', 'simulations']
# Filtered Tokens: ['metronome']
# Filtered Tokens: ['demonstrate', 'synchronisation', 'of', 'five', 'metronomes']
# Filtered Tokens: ['the', 'pendulums', 'in', 'a', 'vectorized', 'approach']
# Filtered Tokens: ['this', 'demo', 'shows', 'how', 'to', 'implement', 'an', 'adaptive', 'median', 'filter', 'in', 'hardware']
# Filtered Tokens: ['solution', 'of', 'differential', 'equation', 'through', 's-function']
# Filtered Tokens: ['design', 'patterns', 'for', 'simulink®', 'functions', 'inside', 'stateflow®', 'requires', 'r2008b', 'or', 'later']
# Filtered Tokens: ['a', 'simulink', 'model', 'implementing', 'a', 'dif', 'fft', 'algorithm', 'modeled', 'completely', 'using', 'embedded', 'matlab', 'blocks']
# Filtered Tokens: ['simple', 'use', 'case', 'of', 'the', 'xpc', 'target', 'driver', 'authoring', 'tool']
# Filtered Tokens: ['describes', 'a', 'block', 'that', 'can', 'be', 'used', 'to', 'delay', 'execution', 'of', 'an', 'xpc', 'target', 'application']
# Filtered Tokens: ['these', 'files', 'show', 'how', 'to', 'match', 'expected', 'theoretical', 'results', 'by', 'monte', 'carlo', 'simulations']
# Filtered Tokens: ['classical', 'envelope', 'detector', 'with', 'diode', 'and', 'rc', 'group', 'and', 'its', 'discretized', 'implementation']
# Filtered Tokens: ['2-goods', '2-consumers', 'general', 'economic', 'equilibrium']
# Filtered Tokens: ['the', 'project', 'describes', 'a', 'link', 'between', 'simmechanics', 'and', 'virtual', 'reality', 'to', 'simulate', 'a', 'robot', 'arm']
# Filtered Tokens: ['these', 'files', 'accompany', 'the', 'seth', 'on', 'simulink®', 'blog', 'post', 'of', 'the', 'same', 'name']
# Filtered Tokens: ['demonstration', 'showing', 'how', 'to', 'log', 'data', 'computed', 'by', 'the', 'simulink®', 'solver', 'at', 'minor', 'time', 'steps']
# Filtered Tokens: ['this', 'is', 'a', 'general', 'purpose', 'controller', 'that', 'i', 'have', 'built', 'using', 'the', 'fuzzy', 'logic', 'rules']
# Filtered Tokens: ['example', 'model', 'that', 'shows', 'hierarchical', 'symbol', 'resolution', 'in', 'action']
# Filtered Tokens: ['a', 'block', 'library', 'containing', 'utility', 'blocks', 'to', 'play', 'music', 'over', 'the', 'internal', 'speaker', 'of', 'a', 'target', 'pc']
# Filtered Tokens: ['this', 'file', 'contains', 'an', 'approximation', 'of', 'the', 'saturation', 'of', 'a', 'function', 'between', 'the', 'values']
# Filtered Tokens: ['a', 'group', 'of', 'delta-sigma', 'simulink-', 'models', 'with', 'dwa', 'mismatch', 'shaping']
# Filtered Tokens: ['this', 'model', 'implements', 'a', 'double', 'pendulum', 'both', 'in', 'simmechanics™', 'and', 'using', 'basic', 'simulink®', 'blocks']
# Filtered Tokens: ['techniques', 'for', 'managing', 'xpc', 'target', 'cpu', 'overloads']
# Filtered Tokens: ['these', 'files', 'accompany', 'my', 'blog', 'post', 'of', 'the', 'same', 'name']
# Filtered Tokens: ['this', 'simmechanics™', 'model', 'implements', 'a', 'wheels', 'rover', 'with', 'suspension', 'and', 'a', 'robotic', 'arm']
# Filtered Tokens: ['supplemental', 'set', 'of', 'matlab', 'm-files', 'and', 'simulink', 'models']
# Filtered Tokens: ['nxt', 'ballbot', 'model-based', 'design', 'based', 'on', 'embedded', 'coder', 'robot', 'nxt']
# Filtered Tokens: ['this', 'simulink', 'block', 'contains', 'a', 'pid', 'controller', 'with', 'anti-windup']
# Filtered Tokens: ['simplified', 'model', 'of', 'an', 'electric', 'wheelchair', 'in', 'simpowersystems']
# Filtered Tokens: ['allows', 'to', 'read', 'input', 'keyboard', 'during', 'simulink', 'simulation']
# Filtered Tokens: ['this', 'demo', 'shows', 'how', 'to', 'use', 'block', 'listeners', 'to', 'view', 'model', 'signals', 'in', 'a', 'matlab', 'user', 'interface']
# Filtered Tokens: ['m-file', 'scripts', 'and', 'simulink', 'models', 'from', 'webinar', 'on', 'may']
# Filtered Tokens: ['the', 'examples', 'provided', 'in', 'this', 'file', 'can', 'be', 'used', 'to', 'teach', 'signal', 'processing', 'courses']
# Filtered Tokens: ['neste', 'modelo', 'foi', 'simulado', 'a', 'tecnica', 'de', 'modulação', 'por', 'largura', 'de', 'pulso', 'senoidal', 'spwm']
# Filtered Tokens: ['simulação', 'do', 'motor', 'de', 'indução', 'trifásico', 'a', 'partir', 'das', 'equações', 'diferenciais']
# Filtered Tokens: ['variable', 'r', 'and', 'x', 'for', 'a', 'catenary', 'system', 'model']
# Filtered Tokens: ['excellent', 'single', 'phase', 'active', 'power', 'filter', 'with', 'closed', 'loop', 'control']
# Filtered Tokens: ['selective', 'harmonic', 'elimination', 'pwm', 'for', '3-phase', 'inverters']
# Filtered Tokens: ['simulation', 'of', 'a', 'direct', 'operated', 'hydraulic', 'relief', 'valve']
# Filtered Tokens: ['cleans', 'simulink', 'models', 'of', 'all', 'scope', 'and', 'display', 'blocks', 'by', 'replacing', 'them', 'with', 'terminator', 'blocks']
# Filtered Tokens: ['i', 'have', 'tried', 'my', 'hand', 'at', 'drawing', 'up', 'a', 'simulink', 'block', 'set', '*very', 'basic*', 'of', 'jpec2000', 'compression']
# Filtered Tokens: ['this', 'demo', 'shows', 'a', 'self', 'modifying', 'masked', 'subsystem', 'to', 'split', 'out', 'the', 'correct', 'subbus', 'from', 'the', 'superbus']
# Filtered Tokens: ['modeling', 'traffic', 'management', 'on', 'a', 'cisco', 'router']
# Filtered Tokens: ['modeling', 'the', 'water', 'surface']
# Filtered Tokens: ['simple', 'method', 'to', 'convert', 'single', 'phase', 'to', 'three-phase', 'by', 'minimum', 'number', 'of', 'switches']
# Filtered Tokens: ['getting', 'the', 'ber', 'out', 'of', 'a', 'multipath', 'non-los', 'channel', 'with', 'bpsk', 'modulation']
# Filtered Tokens: ['simulating', 'simple', 'pendulum', 'in', 'simulink']
# Filtered Tokens: ['torque', 'of', 'electro', 'magnetic', 'torque', 'motor', 'considering', 'magnetic', 'hysterisis']
# Filtered Tokens: ['transient', 'response', 'of', 'electromagnetic', 'torque', 'motor', 'neglecting', 'magnetic', 'hysterisis']
# Filtered Tokens: ['transient', 'response', 'of', 'the', 'exit', 'pressures', 'of', 'first', 'stage', 'of', 'electrohydraulic', 'servovalve']
# Filtered Tokens: ['transient', 'responses', 'of', 'two-stage', 'of', 'servovalve', 'calculated', 'by', 'a', 'transfer', 'function', 'and', 'detailed', 'model']
# Filtered Tokens: ['the', 'simulation', 'for', 'cellular', 'neural', 'networks', 'cnn', 'is', 'built', 'in', 'simulink/matlab']
# Filtered Tokens: ['unscented', 'kalman', 'filtering', 'tutorial', 'simulink', 'and', 'tilt', 'sensor', 'case', 'study']
# Filtered Tokens: ['condensating', 'heat', 'exchanger']
# Filtered Tokens: ['model', 'which', 'changes', 'the', 'parameter', 'of', 'a', 'block', 'with', 'every', 'time', 'step', 'without', 'using', 's-functions']
# Filtered Tokens: ['suspended', 'masses', 'linked', 'by', 'springs', 'and', 'dampers', 'demonstrating', 'basic', 'simmechanics', 'features']
# Filtered Tokens: ['this', 'tool', 'finds', 'optimal', 'gain', 'settings', 'for', 'input', 'devices', 'used', 'in', 'selection/tracking', 'tasks']
# Filtered Tokens: ['simscape™', 'language', 'electromechanical', 'example', 'defining', 'a', 'simple', 'dc', 'motor']
# Filtered Tokens: ['slides', 'and', 'demo', 'files', 'from', 'the', 'webinar', 'introduction', 'to', 'simulink', 'portuguese']
# Filtered Tokens: ['demo', 'files', 'from', 'july', 'webinar']
# Filtered Tokens: ['this', 'is', 'simulation', 'for', 'memristor', 'a', 'memory', 'resistor']
# Filtered Tokens: ['delta-sigma', 'modulated', 'three-phase', 'inverter', 'implementing', 'space', 'vector', 'approach']
# Filtered Tokens: ['voltage', 'quality', 'of', 'grid', 'connected', 'windmills', 'can', 'be', 'resolved', 'using', 'dynamic', 'var', 'technology']
# Filtered Tokens: ['this', 'sample', 'this', 'sample', 'show', 'the', 'simple', 'inverted', 'pendulum', 'control', 'with', 'lqr']
# Filtered Tokens: ['converts', 'the', 'bits', 'hex', 'input', 'into', 'float', 'without', 'using', 'embedded', 'matlab', 'functions']
# Filtered Tokens: ['receive', 'serial', 'data', 'from', 'an', 'instrument', 'or', 'processor', 'and', 'decode', 'it', 'to', 'apply', 'on', 'a', 'plant', 'model']
# Filtered Tokens: ['simscape™', 'language', 'example', 'of', 'nonlinear', 'mechanical', 'springs']
# Filtered Tokens: ['valve-cylinder-piston-spring', 'with', 'hydraulic', 'pump']
# Filtered Tokens: ['this', 'is', 'a', 'video', 'of', 'an', 'introduction', 'crash', 'course', 'for', 'simulink', 'the', 'simulink', 'file', 'is', 'included', 'too']
# Filtered Tokens: ['the', '.m', 'file', 'contains', 'the', 'pendulum', 'parameters', 'and', '.mdl', 'is', 'the', 'simulink', 'model', 'for', 'the', 'pendulum']
# Filtered Tokens: ['this', 'simulink', 'model', 'of', 'magnetic', 'suspension', 'system']
# Filtered Tokens: ['simple', 'radar_system_simulation']
# Filtered Tokens: ['simscape', 'language', 'example', 'showing', 'how', 'to', 'implement', 'and', 'solve', 'a', 'nonlinear', 'second-order', 'ode']
# Filtered Tokens: ['a', 'conventional', 'vehicle', 'electrical', 'system', 'model', 'with', 'alternator', 'battery', 'loads', 'and', 'idle', 'control']
# Filtered Tokens: ['how', 'to', 'use', 'a', 'switcher', 'in', 'simulink', 'when', 'inputs', 'are', 'different', 'sizes']
# Filtered Tokens: ['ask', 'ook', 'fsk', 'qpsk', 'modulators', 'and', 'demodulators']
# Filtered Tokens: ['wind', 'turbine', 'model', 'including', 'blades', 'nacelle', 'pitch', 'and', 'yaw', 'actuation', 'generator', 'and', 'control', 'system']
# Filtered Tokens: ['the', 'rotatory', 'gantry', 'of', 'quanser', 'is', 'simulated', 'with', 'the', 'controller', 'in', 'simmechanics']
# Filtered Tokens: ['servomotor', 'modeling', 'with', 'simmechanics', 'and', 'simelectronics']
# Filtered Tokens: ['this', 'helps', 'you', 'get', 'started', 'with', 'simulink', '3d', 'animation', 'formerly', 'known', 'as', 'virtual', 'reality', 'toolbox']
# Filtered Tokens: ['amplitude', 'modulation', 'and', 'demodulation']
# Filtered Tokens: ['cardiology', 'simulink', 'model', 'cardiac', 'cells', 'heart', 'model', 'relaxation', 'oscillator', 'create', 'new', 'blocks']
# Filtered Tokens: ['example', 'showing', 'a', 'workaround', 'for', 'input', 'bounds', 'are', 'out', 'of', 'range', 'using', 'busobjects']
# Filtered Tokens: ['it', 'is', 'heart', 'vi1', 'with', 'simulink', 'new', 'block', 'function']
# Filtered Tokens: ['new', 'block', 'library', 'simulink']
# Filtered Tokens: ['new', 'block', 'library', 'simulink', 'detection', 'frequency']
# Filtered Tokens: ['new', 'block', 'library', 'simulink', 'heart', 'vi1']
# Filtered Tokens: ['block', 'library', 'simulink', 'heartvi1']
# Filtered Tokens: ['detector', 'frequency', 'new', 'block', 'simulink']
# Filtered Tokens: ['new', 'block', 'simulink', 'library']
# Filtered Tokens: ['training', 'new', 'block', 'library', 'simulink', 'in', 'cardiology']
# Filtered Tokens: ['training', 'new', 'block', 'library', 'simulink', 'in', 'cardiology']
# Filtered Tokens: ['students', 'training', 'block', 'non', 'linear', 'oscillator', 'vi1']
# Filtered Tokens: ['training', 'for', 'students', 'new', 'block', 'library', 'in', 'cardiology', 'with', 'simulink']
# Filtered Tokens: ['block', 'simulink', 'signal', 'library', 'called', 'phase', 'filter']
# Filtered Tokens: ['extension', 'of', 'the', 'bouncing', 'ball', 'demo', 'for', 'the', 'getting', 'started', 'series', 'demos']
# Filtered Tokens: ['heart', 'vi1', 'simulink']
# Filtered Tokens: ['this', 'demo', 'file', 'shows', 'new', 'capabilities', 'for', 'pid', 'controller', 'design', 'and', 'tuning', 'in', 'matlab', 'and', 'simullink']
# Filtered Tokens: ['pllvi1', 'new', 'block', 'simulink']
# Filtered Tokens: ['new', 'block', 'simulink', 'chao', 'control']
# Filtered Tokens: ['new', 'block', 'simulink', 'of', 'heart', 'frequency', 'and', 'blood', 'pressure']
# Filtered Tokens: ['block', 'to', 'simulate', 'the', 'effect', 'of', 'pressure', 'and', 'temperature', 'on', 'the', 'hydraulic', 'fluids']
# Filtered Tokens: ['part', 'of', 'a', 'tool', 'box', 'to', 'generalize', 'the', 'simulation', 'of', 'a', 'hydraulic', 'system']
# Filtered Tokens: ['simulation', 'for', 'chua', "'s", 'system']
# Filtered Tokens: ['cascade', 'of', 'chua', "'s", 'systems', 'and', 'application', 'in', 'secure', 'communications']
# Filtered Tokens: ['simulink', 'model', 'for', 'observer', 'based', 'synchronization', 'in', 'chua', "'s", 'systems']
# Filtered Tokens: ['this', 'file', 'shows', 'pid', 'controller', 'tuning', 'in', 'matlab', 'and', 'simullink', 'for', 'dc', 'motor', 'control']
# Filtered Tokens: ['heartvi19', 'simulink', 'new', 'version']
# Filtered Tokens: ['model', 'of', 'a', 'hybrid-electric', 'vehicle', 'that', 'can', 'be', 'configured', 'for', 'real-time', 'simulation']
# Filtered Tokens: ['new', 'blocks', 'simulink', 'heart', 'simulator', 'investigations']
# Filtered Tokens: ['puedes', 'usarlo', 'para', 'ver', 'que', 'funcion', 'tiene', 'cada', 'bloque', 'para', 'obtener', 'un', 'codigo', 'manchester']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['involves', 'translation', 'of', 'matlab/simulink', 'models', 'to', 'spec', 'c', 'specification', 'models']
# Filtered Tokens: ['video', 'communication', 'system', 'with', 'mpeg-1', 'stages', 'of', 'source', 'channel', 'encoding', 'modulation', 'channel']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['this', 'is', 'a', 'video', 'communication', 'system', 'with', 'encoding', 'modulation', 'channel', 'models']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['simulink', 'model', 'of', 'a', 'monopod', 'hopper', 'with', 'degrees', 'of', 'freedom']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulator', 'simulink']
# Filtered Tokens: ['global', 'heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['the', 'objective', 'is', 'to', 'produce', 'an', 'output', 'of', 'bipolar', '150v', 'and', 'a', 'current', 'of', '4amps', 'bipolar']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['cardiac', 'reentrance', 'vi1', 'block', 'simulink']
# Filtered Tokens: ['compiling', 'problems', 'heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['use', 'stop', 'block', 'to', 'stop', 'a', 'simulation', 'in', 'steady', 'state', 'condition']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['simulink', 'block', 'and', 'pde', 'application', 'theory']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['achieving', 'quality', 'direct', 'connectivity', 'pi-regulator']
# Filtered Tokens: ['problems', 'with', 'torque', 'measurement', 'with', 'simelectronics', 'induction', 'drive', 'drive', 'a', 'simhydraulics', 'pump']
# Filtered Tokens: ['issues', 'with', 'running', 'a', 'pump', 'via', 'speed', 'from', 'asynchronous', 'motor']
# Filtered Tokens: ['in', 'simhydraulics', 'with', 'simelecttronics', 'motor']
# Filtered Tokens: ['simulateur', 'cardiaque', 'vi1', 'simulink']
# Filtered Tokens: ['cardiac', 'block', 'vi1', 'lirary', 'simulink']
# Filtered Tokens: ['heart', 'vi1', 'simulink', 'simulateur', 'cardiaque']
# Filtered Tokens: ['heart', 'vi1', 'simulink', 'simulateur', 'cardiaque']
# Filtered Tokens: ['accumulator', 'application', 'for', 'protection', 'against', 'water', 'hammer']
# Filtered Tokens: ['calculation', 'of', 'equivalent', 'bulk', 'modulus', 'of', 'oil-air', 'mixture']
# Filtered Tokens: ['simulation', 'of', 'hydraulic', 'servo', 'actuator']
# Filtered Tokens: ['calculation', 'of', 'the', 'stiffness', 'of', 'a', 'hydraulic', 'spring']
# Filtered Tokens: ['simulation', 'of', 'hydraulic', 'pipe', 'based', 'on', 'lumped', 'parameter', 'model']
# Filtered Tokens: ['this', 'file', 'contains', 'a', 'subsystem', 'that', 'performs', 'a', 'one-to-one', 'mapping', 'from', '-pi', 'pi', 'to', '0,2*pi']
# Filtered Tokens: ['kalman', 'filtering', 'algorithm', 'to', 'track', 'an', 'object', 'and', 'generating', 'c', 'source', 'code', 'for', 'implementation']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink', 'block']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['modeling', 'of', 'dephosphyllation', 'and', 'phoshyllation']
# Filtered Tokens: ['three', 'level', 'diode', 'clamped', 'pwm', 'based', 'inverter']
# Filtered Tokens: ['single', 'phase', 'square', 'wave', 'inverter']
# Filtered Tokens: ['unipolar', 'sinosoidal', 'pwm', 'based', 'single', 'phase', 'inverter']
# Filtered Tokens: ['sinosoidal', 'pwm', 'based', 'single', 'phase', 'inverter']
# Filtered Tokens: ['quasi', 'square', 'wave', 'based', 'single', 'phase', 'inverter']
# Filtered Tokens: ['degree', 'conduction', 'based', 'three', 'phase', 'inverter']
# Filtered Tokens: ['degree', 'conduction', 'based', 'three', 'phase', 'inverter']
# Filtered Tokens: ['single', 'phase', 'cyclo', 'converter', '50hz', 'to', 'lower', 'frequencies', 'conversion']
# Filtered Tokens: ['models', 'and', 'white', 'paper', 'on', 'obtaining', 'realistic', 'parameter', 'values', 'from', 'data', 'sheets', 'and', 'measured', 'data']
# Filtered Tokens: ['svpwm', 'based', 'three', 'phase', 'inverter']
# Filtered Tokens: ['svpwm', 'based', 'inverter', 'state', 'space', 'filter', 'model']
# Filtered Tokens: ['three', 'phase', 'three', 'level', 'spwm', 'inverter']
# Filtered Tokens: ['here', 'is', 'a', 'three', 'phase', 'inverter', 'block', 'diagram', 'as', 'your', 'reference']
# Filtered Tokens: ['heart', 'vi1', 'simulink', 'simulator']
# Filtered Tokens: ['heart', 'vi1', 'simulator', 'simulink']
# Filtered Tokens: ['pulse', 'analysis']
# Filtered Tokens: ['this', 'cycloconverter', 'converts', 'the', 'ac', 'frequency', 'to', 'ac', 'frequency', 'without', 'the', 'use', 'of', 'dc', 'link']
# Filtered Tokens: ['this', 'model', 'drives', 'a', 'single', 'phase', 'motor', 'with', 'the', 'help', 'of', 'quasi', 'square', 'wave', 'inverter']
# Filtered Tokens: ['five', 'level', 'three', 'phase', 'inverter']
# Filtered Tokens: ['this', 'file', 'is', 'about', 'the', 'working', 'of', 'modified', 'sub', 'oscillation', 'method', 'of', 'generating', 'pwm']
# Filtered Tokens: ['buck', 'converter']
# Filtered Tokens: ['buck', 'converter']
# Filtered Tokens: ['digitally', 'controlled', 'buck', 'converter', 'with', 'and', 'without', 'load', 'transients']
# Filtered Tokens: ['space', 'vector', 'pwm', 'for', 'three', 'phase', 'inverter']
# Filtered Tokens: ['a', 'simple', 'diode', 'based', 'cycloconverter', 'with', 'only', 'frequency', 'control', 'the', 'output', 'is', 'twice', 'as', 'the', 'input']
# Filtered Tokens: ['boost', 'converter']
# Filtered Tokens: ['boost', 'converter']
# ...
# Filtered Tokens: ['a', 'single', 'phase', 'stand-alone', 'inverter', 'fed', 'by', 'mppt', 'converter', 'interfaced', 'without', 'energy', 'storage']
# Filtered Tokens: ['output', 'voltage', 'control', 'of', 'boost', 'dc-dc', 'converter']
# Filtered Tokens: ['three', 'phase', 'off-grid', 'inverter', 'space', 'vector', 'control', 'in', 'modified', 'synchronous', 'reference', 'frame']
# Filtered Tokens: ['a', 'three', 'phase', 'vsi', 'is', 'controlled', 'as', 'a', 'rectifier', 'in', 'synchronous', 'reference', 'frame']
# Filtered Tokens: ['perturb', 'and', 'observe', 'mppt', 'control', 'dc-dc', 'boost', 'converter']
# Filtered Tokens: ['the', 'svpwm', 'technique', 'is', 'the', 'most', 'suitable', 'one', 'for', 'deploying', 'to', 'dsp', 'and', 'microcontrollers', 'since', 'these', 'devices', 'have', 'dedicated', 'h/w', 'resources']
# Filtered Tokens: ['using', 'model', 'based', 'design', 'for', 'code', 'generation', 'a', 'hands-on', 'experience']
# Filtered Tokens: ['this', 'interactive', 'demo', 'performs', 'photovoltaic', 'panel', 'maximum', 'power', 'point', 'tracking', 'based', 'on', 'perturb', 'observe', 'algorithm']
# Filtered Tokens: ['separately', 'excited', 'dc', 'motor', 'chopper', 'drive']
# Filtered Tokens: ['single', 'phase', 'statcom', 'and', 'active', 'power', 'filter', 'control', 'in', 'synchronous', 'reference', 'frame']
# Filtered Tokens: ['single', 'phase', 'unity', 'power', 'factor', 'converter', 'control', 'in', 'synchronous', 'reference', 'frame']
# Filtered Tokens: ['variable', 'voltage', 'variable', 'frequency', 'open', 'loop', 'control', 'of', 'single', 'phase', 'induction', 'motor']
# Filtered Tokens: ['variable', 'voltage', 'variable', 'frequency', 'open', 'loop', 'control', 'of', 'three', 'phase', 'induction', 'motor']
# Filtered Tokens: ['mcgill', 'formula', 'electric', 'builds', 'a', 'fully', 'electric', 'fsae', 'car', 'and', 'is', 'located', 'in', 'montreal', 'canada', 'this', 'is', 'our', 'first', 'simulink', 'torque', 'controller']
# Filtered Tokens: ['a', 'simulink', 'model', 'of', 'power', 'converters', 'that', 'step', 'up', 'dc', 'voltage', 'and', 'convert', 'it', 'into', 'an', 'ac', 'voltage', 'waveform']
# Filtered Tokens: ['this', 'document', 'presents', 'the', 'fault', 'detection', 'and', 'classification', 'of', 'power', 'electronic', 'systems', 'using', 'vector', 'measurement', 'units', 'pmu']
# Filtered Tokens: ['simple', 'rf', 'jammer', 'model', 'that', 'emulates', 'electronic', 'warfare']
# Filtered Tokens: ['an', 'application', 'of', 'model-reference', 'adaptive', 'control', 'mras', 'for', 'state', 'feedback', 'speed', 'controller', 'sfc', 'for', 'pmsm', 'drive']
# Filtered Tokens: ['a', 'variable', 'voltage', 'variable', 'frequency', 'ac-ac', 'system', 'using', 'back', 'to', 'back', 'connected', 'single', 'phase', 'vsi']
# Filtered Tokens: ['a', 'variable', 'voltage', 'variable', 'frequency', 'ac-ac', 'system', 'using', 'back', 'to', 'back', 'connected', 'single', 'phase', 'vsi', 'and', 'load', 'side', 'uncontrolled', 'rectifier']
# Filtered Tokens: ['a', 'variable', 'voltage', 'variable', 'frequency', 'galvanically', 'isolated', 'ac-ac', 'system', 'using', 'back', 'to', 'back', 'connected', 'single', 'phase', 'vsi']
# Filtered Tokens: ['this', 'model', 'can', 'explain', 'how', 'to', 'model', 'non', 'linear', 'pv', 'system', 'and', 'can', 'get', 'p-v', 'and', 'i-v', 'graphs']
# Filtered Tokens: ['temperature', 'parameter', 'is', 'included', 'in', 'modeling', 'of', 'pv', 'system', 'and', 'can', 'get', 'p-v', 'and', 'i-v', 'curves']
# Filtered Tokens: ['this', 'type', 'of', 'inverter', 'requires', 'two', 'power', 'electronics', 'switches', 'mosfet', 'the', 'mosfet', 'or', 'igbt', 'is', 'used', 'for', 'switching', 'purpose']
# Filtered Tokens: ['in', 'full', 'bridge', 'inverter', 'also', 'we', 'need', 'only', 'two', 'gate', 'pulses', 'which', 'is', 'same', 'as', 'half', 'bridge', 'inverter', 'one', 'gate', 'pulse', 'is', 'for', 'mosfet', 'and', 'and', 'i']
# Filtered Tokens: ['s', 'the', 'phase', 'delay', 'is', 'in', 'seconds', 'so', 'the', 'phase', 'delay', 'of', '2nd', 'pulse', 'generator', 'will', 'be', '2e-3', 'and', 'so', 'on', 'all', 'the', 'six', 'pulse', 'generators', 'conn']
# Filtered Tokens: ['the', 'circuit', 'consist', 'of', 'four', 'thyristors', 't1', 't2', 't3', 'and', 't4', 'a', 'voltage', 'source', 'vs', 'and', 'a', 'rload']
# Filtered Tokens: ['the', 'circuit', 'consist', 'of', 'thyristors', 't1', 't2', 't3', 't4', 't5', 't6', 'a', 'three', 'phase', 'supply', 'and', 'a', 'r', 'load']
# Filtered Tokens: ['this', 'charge', 'controller', 'model', 'perform', 'solar', 'photovoltaic', 'maximum', 'power', 'point', 'tracking', 'to', 'charge', 'lead', 'acid', 'battery']
# Filtered Tokens: ['this', 'off-grid', 'inverter', 'model', 'is', 'capable', 'to', 'produce', 'ac', 'sinewave', 'output', 'voltage', 'at', 'v', 'hz', 'up', 'to', 'kw', 'power', 'from', 'a', 'v', 'battery']
# Filtered Tokens: ['matlab-simulink', 'model', 'of', 'ieee', 'bus', 'system', 'baran', 'and', 'wu']
# Filtered Tokens: ['a', 'boost', 'converter', 'is', 'a', 'dc/dc', 'power', 'converter', 'which', 'steps', 'up', 'voltage', 'from', 'its', 'input', 'source', 'to', 'its', 'output', 'load', 'in', 'continuous', 'conduction', 'm']
# Filtered Tokens: ['boost', 'converter', 'is', 'a', 'converter', 'which', 'converts', 'variable', 'dc', 'voltage', 'to', 'required', 'dc', 'voltage']
# Filtered Tokens: ['online', 'optimization', 'of', 'energy', 'storage', 'actions', 'in', 'a', 'microgrid', 'given', 'system', 'constraints', 'and', 'pricing']
# Filtered Tokens: ['five', 'level', 'h-bridge', 'inverter']
# Filtered Tokens: ['push', 'pull', 'using', 'simscape', 'specialized', 'technology', 'library']
# Filtered Tokens: ['a', 'accurate', 'model', 'to', 'calculate', 'acceleration', 'and', 'many', 'other', 'parameters', 'of', 'a', 'tesla', 'model', 's', 'p100d', 'such', 'as', 'any', 'other', 'car']
# Filtered Tokens: ['the', 'concept', 'of', 'multilevel', 'inverter', 'mli', 'is', 'kind', 'of', 'modification', 'of', 'two-level', 'inverter']
# Filtered Tokens: ['an', 'inverter', 'also', 'named', 'as', 'power', 'inverter', 'is', 'an', 'electrical', 'power', 'device', 'which', 'is', 'used', 'to', 'convert', 'direct', 'current', 'dc', 'into', 'a.c']
# Filtered Tokens: ['to', 'control', 'speed', 'of', 'induction', 'motor', 'drive', 'foc', 'is', 'one', 'of', 'the', 'method']
# Filtered Tokens: ['mpcc', 'uses', 'predictive', 'current', 'equation', 'of', 'im']
# Filtered Tokens: ['mptfc', 'is', 'inspired', 'from', 'mpcc', 'and', 'dtc', 'structures']
# Filtered Tokens: ['open', 'loop', 'performance', 'of', 'induction', 'motor', 'analysed', 'which', 'is', 'fed', 'with', 'level', 'npc', 'inverter', 'with', 'space', 'vector', 'modulation']
# Filtered Tokens: ['this', 'dc', 'to', 'dc', 'buck', 'converter', 'works', 'in', 'two', 'states', 'one', 'when', 'switch', 'is', 'closed', 'and', 'second', 'one', 'when', 'switch', 'is', 'opened']
# Filtered Tokens: ['single', 'phase', 'full', 'wave', 'ac', 'to', 'dc', 'converter', 'using', 'bidirectionalswitches']
# Filtered Tokens: ['matlab', 'simulation', 'on', 'single', 'phase', 'fully', 'controlled', 'fed', 'dc', 'drive']
# Filtered Tokens: ['close', 'loop', 'control']
# Filtered Tokens: ['three', 'phase', 'grid', 'connected', 'pv', 'system', 'of', 'rating', '33kw', 'is', 'simulated', 'under', 'linear', 'and', 'non-linear', 'load', 'conditions', 'with', 'power', 'quality', 'improvement']
# Filtered Tokens: ['brush', 'less', 'exciter', 'with', 'pss', '2a']
# Filtered Tokens: ['models', 'for', 'the', 'solar', 'panel', 'example', 'shown', 'in', 'the', 'getting', 'started', 'with', 'simulink', 'for', 'controls', 'video']
# Filtered Tokens: ['x-y', 'plotter', 'with', 'animation', 'and', 'reference', 'curve']
# Filtered Tokens: ['particle', 'swarm', 'optimization', 'maximum', 'power', 'point', 'tracking', 'boost', 'converter']
# Filtered Tokens: ['igbt', 'and', 'and', 'inverse', 'of', 'this', 'gate', 'pulse', 'is', 'for', 'igbt', 'and']
# Filtered Tokens: ['this', 'type', 'of', 'inverter', 'requires', 'two', 'power', 'electronics', 'switches', 'mosfet', 'the', 'mosfet', 'or', 'igbt', 'is', 'used', 'for', 'switching', 'purpose']
# Filtered Tokens: ['the', 'pv', 'system', 'is', 'connected', 'to', 'grid', 'through', 'inverter', 'which', 'can', 'act', 'as', 'mppt', 'of', 'pv', 'system', 'in', 'this', 'model']
# Filtered Tokens: ['current', 'controller', 'based', 'three', 'level', 'inverter', 'is', 'designed', 'based', 'on', 'space', 'vector', 'modulation', 'technique']
# Filtered Tokens: ['level', 'diode', 'clamped', 'inverter', 'with', 'spwm']
# Filtered Tokens: ['facts', 'device', 'used', 'for', 'countering', 'the', 'ferranti', 'effect']
# Filtered Tokens: ['the', 'simulink', 'model', 'of', 'a', 'high-performance', 'single-phase', 'sft-based', 'pll', 'that', 'gives', 'outstanding', 'performance', 'is', 'given']
# Filtered Tokens: ['frequency', 'adaptive', 'sliding', 'fourier', 'transform', 'for', 'synchronizing', 'vsci', 'to', 'the', 'utility', 'grid']
# Filtered Tokens: ['this', 'is', 'a', 'stpa', 'systems', 'theoretic', 'process', 'analysis', 'tool', 'using', 'simulink', 'and', 'matlab']
# Filtered Tokens: ['red', 'green', 'blue', 'light', 'emitting', 'diode', 'sink']
# Filtered Tokens: ['dynamic', 'performance', 'of', 'a', 'scig', 'wind', 'energysystem', 'during', 'system', 'start-up']
# Filtered Tokens: ['1.5mw', 'wind', 'generation', 'plant', 'using', 'scig']
# Filtered Tokens: ['indranil', 'saaki']
# Filtered Tokens: ['this', 'example', 'shows', 'how', 'to', 'build', 'physical', 'component', 'model', 'based', 'on', 'physical', 'connections', 'to', 'modeling', 'free', 'fall', 'of', 'a', 'steel', 'ball', 'using', 'simulink']
# Filtered Tokens: ['modeling', 'motion', 'of', 'a', 'ball', 'that', 'is', 'thrown', 'upward', 'at', 'an', 'angle', 'to', 'the', 'horizontal', 'in', 'the', 'earth', 's', 'gravitational', 'field', 'using', 'simulink', 'simscape']
# Filtered Tokens: ['ac', 'voltage', 'controller']
# Filtered Tokens: ['in', 'this', 'model', 'basic', 'simulation', 'of', 'hall', 'sensor', 'based', 'bldc', 'drive', 'is', 'done', 'with', 'all', 'the', 'currents', 'back', 'emfs', 'torque', 'speed', 'and', 'other', 'quantities']
# Filtered Tokens: ['model', 'is', 'done', 'with', 'using', 'boost', 'converter', 'equations', 'which', 'will', 'step-up', 'the', 'voltage', 'w.r.t', 'the', 'input', 'voltage', 'depending', 'upon', 'the', 'duty', 'cycle']
# Filtered Tokens: ['about', 'simulation', 'hvdc', 'hvac']
# Filtered Tokens: ['make', 'output', 'slowly', 'close', 'input', 'when', 'input', 'change', 'very', 'big']
# Filtered Tokens: ['modelling', 'and', 'controller', 'of', 'microgrid', 'integration', 'of', 'hybrid', 'pv/', 'wind', 'battery', 'management', 'system', 'using', 'fuzzy', 'logic', 'controller']
# Filtered Tokens: ['this', 'circuit', 'demonstrates', 'how', 'solid', 'state', 'relay', 'can', 'be', 'constructed', 'using', 'a', 'mosfet', 'and', 'four', 'diodes']
# Filtered Tokens: ['boost', 'converter', 'with', 'closed', 'loop', 'control']
# Filtered Tokens: ['a', 'ćuk', 'converter', 'transforms', 'a', 'dc', 'voltage', 'at', 'the', 'input', 'to', 'a', 'dc', 'voltage', 'at', 'the', 'output', 'with', 'reversed', 'polarity']
# Filtered Tokens: ['a', 'buck', 'converter', 'steps', 'down', 'a', 'dc', 'voltage', 'from', 'the', 'input', 'to', 'the', 'output']
# Filtered Tokens: ['a', 'boost', 'converter', 'steps', 'up', 'a', 'dc', 'voltage', 'from', 'the', 'input', 'to', 'the', 'output']
# Filtered Tokens: ['decodes', 'camera', 'link', 'pixel', 'stream', 'of', 'a', 'dalsa', 'spyder', 'camera', 'link', 'line', 'scan', 'camera', '1k', 'pixel', 'model', 'with', 'taps', 'generates', 'working', 'hdl', 'code']
# Filtered Tokens: ['a', 'flyback', 'converter', 'transforms', 'a', 'dc', 'voltage', 'at', 'the', 'input', 'to', 'a', 'dc', 'voltage', 'at', 'the', 'output']
# Filtered Tokens: ['texas', 'instruments', 'multi-channel', 'serial', 'port', 'protocol', 'used', 'by', 'many', 'dsps', 'can', 'be', 'used', 'for', 'high', 'throughput', 'link', 'between', 'fpga', 'and', 'dsp']
# Filtered Tokens: ['a', 'buck-boost', 'converter', 'transforms', 'a', 'positive', 'dc', 'voltage', 'at', 'the', 'input', 'to', 'a', 'negative', 'dc', 'voltage', 'at', 'the', 'output']
# Filtered Tokens: ['the', 'simulink', 'model', 'based', 'on', 'pv', 'system', 'consisting', 'of', 'pv', 'battery', 'converter', 'pi', 'controller', 'inverter', 'and', 'charge', 'controller']
# Filtered Tokens: ['demonstration', 'of', 'setting', 'up', 'a', 'ros', 'action', 'client', 'block', 'in', 'simulink']
# Filtered Tokens: ['this', 'project', 'is', 'solar', 'with', 'fuzzy', 'inference', 'system']
# Filtered Tokens: ['a', 'full', 'wave', 'rectifier', 'is', 'a', 'circuit', 'which', 'converts', 'an', 'ac', 'voltage', 'into', 'a', 'pulsating', 'dc', 'voltage', 'using', 'both', 'half', 'cycles', 'of', 'the', 'applied', 'ac', 'voltag']
# Filtered Tokens: ['an', 'ideal', 'rgb', 'led', 'with', 'common', 'cathode', 'that', 'is', 'implemented', 'using', 'power', 'system', 'blocks']
# Filtered Tokens: ['simulink', 'model', 'of', 'a', 'simple', 'mechanical', 'system', 'using', 'mathematical', 'equation', 'model']
# Filtered Tokens: ['three', 'phase', 'three', 'level', 'inverter']
# Filtered Tokens: ['siemens', 'speed', 'control', 'primary', 'frequency', 'influence']
# Filtered Tokens: ['these', 'double', 'infeed', 'model', 'have', 'real', 'transmission', 'line', 'data', 'of', '132kv', 'and', '160km', 'login', 'of', 'auto', 'reclosing', 'work', 'perfectly']
# Filtered Tokens: ['i', 'created', 'this', 'as', 'a', 'part', 'of', 'my', 'own', 'education', 'of', 'how', 'to', 'build', 'a', 'model', 'for', 'analyzing', 'transients']
# Filtered Tokens: ['single', 'phase', 'fully', 'controlled', 'bridge', 'converter', 'with', 'r', 'rl', 'load', 'with', 'free', 'wheeling', 'diode']
# Filtered Tokens: ['the', 'supplementary', 'damping', 'control', 'is', 'added', 'to', 'the', 'q-axis', 'output', 'of', 'rsc', "'s", 'inner', 'controller.this', 'method', 'was', 'proposed', 'by', 'andres', 'e.leon', 'in']
# Filtered Tokens: ['ai', 'based', 'microgrid', 'integration', 'of', 'hybrid', 'kw', 'pv', 'and', 'wind', 'power', 'system']
# Filtered Tokens: ['pso', 'based', 'mppt', 'controller', 'for', 'w', 'photovoltaic', 'system']
# Filtered Tokens: ['microgrid', 'integration', 'of', 'hybrid', 'pv', 'dfig', 'and', 'battery', 'energy', 'system', 'with', 'ai', 'controller', 'based', 'energy', 'management', 'system']
# Filtered Tokens: ['in', 'this', 'model', 'a', 'microgrid', 'test', 'system', 'based', 'on', 'the', '14-busbar', 'ieee', 'distribution', 'system', 'is', 'proposed']
# Filtered Tokens: ['solar', 'electric', 'vehicle', 'charging', 'station']
# Filtered Tokens: ['solar', 'electric', 'vehicle']
# Filtered Tokens: ['micro', 'gas', 'turbine', 'charging', 'station']
# Filtered Tokens: ['dynamic', 'voltage', 'restorer']
# Filtered Tokens: ['five', 'bus', 'thyristor', 'control', 'series', 'compensator']
# Filtered Tokens: ['power', 'transient', 'stability', 'using', 'pid']
# Filtered Tokens: ['power', 'transient', 'stability', 'using', 'fuzzy', 'controller']
# Filtered Tokens: ['fuzzy', 'controller', 'based', 'vienna', 'rectifier', 'for', 'e', 'vehicle', 'www.pirc.co.in']
# Filtered Tokens: ['simple', 'buck', 'converter', 'work', 'for', 'dynamic', 'load', 'with', 'pid', 'and', 'zvs', 'controller']
# Filtered Tokens: ['a', 'very', 'basic', 'example', 'of', 'physical', 'modeling', 'in', 'simscape']
# Filtered Tokens: ['i2c', 'sensors', 'can', 'be', 'read', 'directly', 'in', 'simulink', 'using', 'the', 'arduino', 'support', 'package', 'with', 'the', 'block', 'i2c', 'master', 'read']
# Filtered Tokens: ['this', 'is', 'the', 'ball', 'on', 'plate', 'simscape', 'model', 'control', 'and', 'diagnostics', 'the', 'hardware', 'has', 'two', 'servos', 'as', 'inputs', 'and', 'position', 'of', 'the', 'ball', 'as', 'output']
# Filtered Tokens: ['single', 'phase', 'dimmer']
# Filtered Tokens: ['ِabb', 'automatic', 'generation', 'control', 'frequency', 'response', 'to', 'area', 'gen.', 'mw', 'automatic', 'generation', 'control', 'by', 'abb', 'gt8c']
# (2724, 1)
